# %% [markdown]
# # Importar Bibliotecas

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import utils

# %% [markdown]
# # Leer dataset como DataFrame

# %%
# Se lee el dataset como csv que fue creado sintéticamente
df = pd.read_csv('../Datasets/dataset.csv')

# Mostramos un resumen del dataset para darnos una idea general de cómo es
df
# Out:
#              id                         nombre  semestre  promedio  ingresos  \
# 0     IDHFI3552  Caridad Leonor Padrón Cavazos         7        86   13580.0
# 1     IDVOH5097       Aurelio Fabiola Anguiano         4        89   15993.0
# 2     IDFYS5079          Omar Amalia Sepúlveda         8        89   11008.0
# 3     IDSCE4123   Pamela Aida Cuellar Valverde         5        62   30926.0
# 4     IDYMU9480          Óscar Olivárez Nájera         7        66   24968.0
# ...         ...                            ...       ...       ...       ...
# 9995  IDURC8308    Inés Cynthia Madrid Salinas         7        86   17337.0
# 9996  IDJLX9083                   Mitzy Puente        10        74       NaN
# 9997  IDNCQ0036                Raquel Longoria         3        91   26994.0
# 9998  IDWJQ8803           Lic. Andrea Cisneros        10        87       NaN
# 9999  IDLPD1164    Maximiliano Alfonso Fuentes         5        68   22850.0
#
#       opinion_campus  trabaja  distancia_universidad  edad tipo_vivienda  \
# 0                 10    False                    NaN    21        Propia
# 1                  4     True                    1.0    22      Alquiler
# 2                  4    False                    1.0    18        Propia
# 3                 10    False                    1.0    17        Propia
# 4                 10    False                    1.0    26      Alquiler
# ...              ...      ...                    ...   ...           ...
# 9995              10     True                    1.0    37      Alquiler
# 9996               1    False                   10.0    17      Alquiler
# 9997              10     True                    NaN    27        Propia
# 9998               7     True                    3.0    26      Alquiler
# 9999               9     True                    NaN    23        Propia
#
#       horas_estudio  desertor
# 0                29         0
# 1                 5         0
# 2                11         0
# 3                12         0
# 4                17         0
# ...             ...       ...
# 9995             70         0
# 9996             88         0
# 9997             71         0
# 9998             74         0
# 9999            100         0
#
# [10000 rows x 12 columns]

# %% [markdown]
# # Ver tipos de datos

# %%
# Nos permite ver si lso datos son booleanos, numéricos reales o enteros, o si son strings (object)
df.dtypes
# Out:
# id                        object
# nombre                    object
# semestre                   int64
# promedio                   int64
# ingresos                 float64
# opinion_campus             int64
# trabaja                     bool
# distancia_universidad    float64
# edad                       int64
# tipo_vivienda             object
# horas_estudio              int64
# desertor                   int64
# dtype: object

# %% [markdown]
# # Calcular modas, medianas y medias

# %% [markdown]
# ## Modas

# %%
# Esta funcion nos devuelve la moda de cada columna del DataFrame
df.mode()
# Out:
#              id            nombre  semestre  promedio  ingresos  \
# 0     IDAAE3765      Bruno Flórez       1.0      74.0    8300.0
# 1     IDAAJ6279  Cornelio Vásquez       NaN       NaN       NaN
# 2     IDAAK9953     Dolores Salas       NaN       NaN       NaN
# 3     IDAAN0414     Gloria Fierro       NaN       NaN       NaN
# 4     IDAAN8457    Isabel Carrión       NaN       NaN       NaN
# ...         ...               ...       ...       ...       ...
# 9995  IDZZR7800               NaN       NaN       NaN       NaN
# 9996  IDZZU2201               NaN       NaN       NaN       NaN
# 9997  IDZZU4785               NaN       NaN       NaN       NaN
# 9998  IDZZU7053               NaN       NaN       NaN       NaN
# 9999  IDZZY4781               NaN       NaN       NaN       NaN
#
#       opinion_campus trabaja  distancia_universidad  edad tipo_vivienda  \
# 0               10.0   False                    1.0  17.0        Propia
# 1                NaN     NaN                    NaN   NaN           NaN
# 2                NaN     NaN                    NaN   NaN           NaN
# 3                NaN     NaN                    NaN   NaN           NaN
# 4                NaN     NaN                    NaN   NaN           NaN
# ...              ...     ...                    ...   ...           ...
# 9995             NaN     NaN                    NaN   NaN           NaN
# 9996             NaN     NaN                    NaN   NaN           NaN
# 9997             NaN     NaN                    NaN   NaN           NaN
# 9998             NaN     NaN                    NaN   NaN           NaN
# 9999             NaN     NaN                    NaN   NaN           NaN
#
#       horas_estudio  desertor
# 0              91.0       0.0
# 1               NaN       NaN
# 2               NaN       NaN
# 3               NaN       NaN
# 4               NaN       NaN
# ...             ...       ...
# 9995            NaN       NaN
# 9996            NaN       NaN
# 9997            NaN       NaN
# 9998            NaN       NaN
# 9999            NaN       NaN
#
# [10000 rows x 12 columns]

# %%
# Ahora vemos las modas pero solo con las columnas que nos interesan (en los nombre no tiene sentido estadístico encontrar la moda)
df[['semestre', 'promedio', 'ingresos', 'opinion_campus', 'distancia_universidad', 'edad', 'tipo_vivienda', 'horas_estudio', 'desertor']].mode()
# Out:
#    semestre  promedio  ingresos  opinion_campus  distancia_universidad  edad  \
# 0         1        74    8300.0              10                    1.0    17
#
#   tipo_vivienda  horas_estudio  desertor
# 0        Propia             91         0

# %% [markdown]
# ## Medianas

# %%
# De igual forma obtenemos las medianas de las columnas que consideramos importantes
df[['semestre', 'promedio', 'ingresos', 'opinion_campus', 'distancia_universidad', 'edad', 'horas_estudio']].median()
# Out:
# semestre                     6.0
# promedio                    80.0
# ingresos                 19972.0
# opinion_campus               8.0
# distancia_universidad        3.0
# edad                        20.0
# horas_estudio               50.0
# dtype: float64

# %% [markdown]
# ## Medias

# %%
# Igual con las medias, o promedios aritméticos
df[['semestre', 'promedio', 'ingresos', 'opinion_campus', 'distancia_universidad', 'edad', 'horas_estudio', 'desertor']].mean()
# Out:
# semestre                     5.497200
# promedio                    79.752400
# ingresos                 20319.281485
# opinion_campus               7.271800
# distancia_universidad        4.264385
# edad                        20.888600
# horas_estudio               50.270400
# desertor                     0.187600
# dtype: float64

# %% [markdown]
# # Comprobar comportamiento de los datos

# %% [markdown]
# Queremos asegurarnos que el dataset se comporte como lo definimos.
# De igual forma aprovechamos para medio sondearlo.

# %%
# En esta celda graficamos el histograma de la variable "semestre"

column = 'semestre'

plt.figure(figsize=(10, 6))
plt.hist(df[column], bins=range(1, 12), edgecolor='black', align='left', rwidth=0.8)

# Customize the x-ticks to match the numbers in the data
plt.xticks(range(min(df[column]), max(df[column])+1 ))

# Show the plot
plt.title(f'Histogram of {column}')
plt.xlabel('Value')
plt.ylabel('Frequency')
plt.show()

# %%
# En esta celda graficamos el histograma de la variable "promedio"

column = 'promedio'

# Define los bordes de los bins para crear exactamente 10 barras entre 60 y 100
bins = np.linspace(60, 100, 11)  # 10 intervalos -> 11 bordes

plt.figure(figsize=(10, 6))
plt.hist(df[column], bins=bins, edgecolor='black', align='mid', rwidth=0.8)

# Ajusta las marcas del eje X para que coincidan con los valores medios de los bins
plt.xticks(np.arange(60, 101, 4))  # Aquí 4 es el ancho de cada intervalo (100-60)/10

# Mostrar el gráfico con título y etiquetas
plt.title(f'Histogram of {column}')
plt.xlabel('Value')
plt.ylabel('Frequency')
plt.show()

# %%
# En esta celda graficamos el histograma de la variable "ingresos"

column = 'ingresos'

plt.figure(figsize=(10, 6))
plt.hist(df[column], bins=np.arange(int(min(df[column])), int(max(df[column])) + 2, max(df[column] - min(df[column]))/10), 
         edgecolor='black', align='left', rwidth=0.8)

# Customize the x-ticks to match the numbers in the data
plt.xticks(np.arange(min(df[column]), max(df[column])+1, 5000))

# Show the plot
plt.title(f'Histogram of {column}')
plt.xlabel('Value')
plt.ylabel('Frequency')
plt.show()

# %%
# En esta celda graficamos el histograma de la variable "opinion_campus"

column = 'opinion_campus'

plt.figure(figsize=(10, 6))
plt.hist(df[column], bins=range(1, 12), edgecolor='black', align='left', rwidth=0.8)

# Customize the x-ticks to match the numbers in the data
plt.xticks(range(min(df[column]), max(df[column])+1 ))

# Show the plot
plt.title(f'Histogram of {column}')
plt.xlabel('Value')
plt.ylabel('Frequency')
plt.show()

# %%
# En esta celda graficamos el histograma de la variable "trabaja"

column = 'trabaja'

plt.figure(figsize=(10, 6))
plt.hist(df[column].astype(int), 
         bins=[-0.5, 0.5, 1.5],  # Definimos bordes para alinear las barras con 0 y 1
         edgecolor='black', align='mid', rwidth=0.8)

# Configurar las etiquetas del eje X como 'False' y 'True'
plt.xticks([0, 1], labels=['False', 'True'])

# Títulos y etiquetas
plt.title(f'Histogram of {column}')
plt.xlabel('Value')
plt.ylabel('Frequency')
plt.show()

# %%
# En esta celda graficamos el histograma de la variable "distancia_universidad"

column = 'distancia_universidad'

plt.figure(figsize=(10, 6))
plt.hist(df[column], 
         bins=10, 
         edgecolor='black', align='left', rwidth=0.8)
plt.title(f'Histogram of {column}')
plt.xlabel('Value')
plt.ylabel('Frequency')
plt.show()

# %%
# En esta celda graficamos el histograma de la variable "edad"

column = 'edad'

plt.figure(figsize=(10, 6))
plt.hist(df[column], 
         bins=np.arange(int(min(df[column])), int(max(df[column])) + 2, max(df[column] - min(df[column]))/10), 
         edgecolor='black', align='left', rwidth=0.8)
plt.title(f'Histogram of {column}')
plt.xlabel('Value')
plt.ylabel('Frequency')
plt.show()

# %%
# En esta celda graficamos el histograma de la variable "tipo_vivienda"

column = 'tipo_vivienda'

plt.figure(figsize=(10, 6))
plt.hist(df[column], 
         bins=2, 
         edgecolor='black', align='mid', rwidth=0.8)
plt.title(f'Histogram of {column}')
plt.xlabel('Value')
plt.xticks(df[column].unique())
plt.ylabel('Frequency')
plt.show()

# %%
# En esta celda graficamos el histograma de la variable "horas_estudio"

column = 'horas_estudio'

plt.figure(figsize=(10, 6))
plt.hist(df[column], 
         bins=np.arange(int(min(df[column])), int(max(df[column])) + 2, max(df[column] - min(df[column]))/10), 
         edgecolor='black', align='left', rwidth=0.8)
plt.title(f'Histogram of {column}')
plt.xlabel('Value')
plt.ylabel('Frequency')
# En esta celda graficamos el histograma de la variable "semestre"plt.show()
# Out:
# Text(0, 0.5, 'Frequency')

# %%
# En esta celda graficamos el histograma de la variable clase "desertor"

column = 'desertor'

plt.figure(figsize=(10, 6))
plt.hist(df[column], 
         bins=2, 
         edgecolor='black', align='mid', rwidth=0.8)
plt.title(f'Histogram of {column}')
plt.xlabel('Value')
plt.xticks(df[column].unique())
plt.ylabel('Frequency')
plt.show()

# %% [markdown]
# # Ahora con todos los datos estadisticos

# %%
# Esta funcion nos da directamente todos los datos estadísticos del DataFrame, para no sacarlos individualmente, también incluye los cuartiles
df.describe()
# Out:
#            semestre      promedio      ingresos  opinion_campus  \
# count  10000.000000  10000.000000   8107.000000    10000.000000
# mean       5.497200     79.752400  20319.281485        7.271800
# std        2.893964     11.743368   8143.080849        2.833254
# min        1.000000     60.000000   8300.000000        1.000000
# 25%        3.000000     70.000000  14035.000000        5.000000
# 50%        6.000000     80.000000  19972.000000        8.000000
# 75%        8.000000     90.000000  25908.500000       10.000000
# max       10.000000    100.000000  49329.000000       10.000000
#
#        distancia_universidad          edad  horas_estudio      desertor
# count            7977.000000  10000.000000   10000.000000  10000.000000
# mean                4.264385     20.888600      50.270400      0.187600
# std                 3.632390      3.855733      35.786128      0.390412
# min                 1.000000     17.000000       1.000000      0.000000
# 25%                 1.000000     17.000000      16.000000      0.000000
# 50%                 3.000000     20.000000      50.000000      0.000000
# 75%                 7.000000     23.000000      85.000000      0.000000
# max                25.000000     39.000000     100.000000      1.000000

# %%
# Obtenemos el Coeficiente de Variación de cada variable
CV = df.describe().loc['std']/df.describe().loc['mean']
CV
# Out:
# semestre                 0.526443
# promedio                 0.147248
# ingresos                 0.400756
# opinion_campus           0.389622
# distancia_universidad    0.851797
# edad                     0.184586
# horas_estudio            0.711873
# desertor                 2.081087
# dtype: float64

# %% [markdown]
# # Distribuciones con distintas propiedades estadísticas

# %% [markdown]
# En esta sección queremos mostrar diferentes tipos de distribuciones con comportamientos diferentes dadas sus medias, medianas y desviación estándar

# %%
# Aproximamos un conjunto de datos con media 50, mediana 50, y desviación estándar 10

desired_sample_size = 300
desired_min = 1
desired_max = 100
desired_median = 50
desired_mean = 50
desired_std = 5
mean_error = 5
std_error = 5


list_numbers_1 = utils.generate_numbers(desired_sample_size, desired_min, desired_max, desired_median, desired_mean, desired_std, mean_error, std_error, max_iter=10000)

print("List:", list_numbers_1)
print("Mean:", np.mean(list_numbers_1))
print("Standard Deviation:", np.std(list_numbers_1))
print("Median:", np.median(list_numbers_1))
# Out:
# List: [1.0, 30.91039302729273, 33.89209315993989, 33.89209316993989, 33.95788990974567, 33.95788991974567, 33.95788992974567, 33.95788993974567, 34.47328904153535, 34.73159064451941, 34.73159065451941, 34.73159066451941, 34.73159067451941, 34.73159068451941, 34.73159069451941, 34.73159070451941, 34.73159071451941, 34.731590724519414, 34.731590734519415, 36.1135319952587, 36.1135320052587, 36.333731734218915, 36.64563755150756, 36.64563756150756, 37.20962323239145, 37.278551976957296, 37.2785519869573, 37.2785519969573, 37.2785520069573, 37.2785520169573, 37.57109117120009, 37.57109118120009, 37.57109119120009, 37.57109120120009, 37.57109121120009, 37.57109122120009, 37.57109123120009, 38.10900690964119, 38.10900691964119, 38.8325339523488, 38.8325339623488, 39.284475396385176, 39.28447540638518, 39.28447541638518, 39.28447542638518, 39.59892665717045, 39.59892666717045, 39.598926677170454, 39.598926687170454, 39.598926697170455, 39.598926707170456, 39.59892671717046, 39.59892672717046, 39.642855051682815, 39.642855061682816, 39.64285507168282, 39.6893041732329, 39.86436054154629, 39.90259628299524, 39.90259629299524, 39.90259630299524, 39.90259631299524, 39.902596322995244, 39.902596332995245, 39.902596342995245, 40.517393454152135, 40.517393464152136, 40.831548778725356, 41.21649046685386, 41.435986502513316, 41.85815016838797, 41.85815017838797, 41.858150188387974, 41.858150198387975, 41.858150208387976, 41.858150218387976, 42.23968923133519, 43.087603780303404, 43.087603790303405, 43.087603800303405, 43.087603810303406, 43.08760382030341, 43.08760383030341, 43.08760384030341, 43.33319356503567, 44.597737070644655, 44.597737080644656, 44.59773709064466, 45.99576512852913, 45.99576513852913, 45.99576514852913, 45.99576515852913, 45.99576516852913, 45.99576517852913, 45.995765188529134, 45.995765198529135, 45.995765208529136, 45.99576521852914, 45.99576522852914, 45.99576523852914, 45.99576524852914, 45.99576525852914, 45.99576526852914, 45.99576527852914, 45.99576528852914, 45.99576529852914, 46.11517949565072, 46.11517950565072, 46.19955531043434, 46.19955532043434, 46.19955533043434, 46.199555340434344, 46.53579922838369, 46.53579923838369, 46.53579924838369, 46.53579925838369, 46.53579926838369, 46.53579927838369, 46.53579928838369, 46.66843925096369, 46.66843926096369, 46.66843927096369, 46.66843928096369, 46.66843929096369, 47.50026748657711, 47.746030156357385, 48.324529753710515, 48.324529763710515, 48.324529773710516, 48.658612905675454, 48.658612915675455, 48.658612925675456, 48.65861293567546, 48.65861294567546, 48.65861295567546, 48.65861296567546, 48.78780033636497, 48.78780034636497, 48.78780035636497, 49.170338822714314, 49.170338832714314, 49.170338842714315, 49.170338852714316, 49.466454325477926, 49.46645433547793, 49.46645434547793, 49.98091934281244, 49.98091935281244, 49.98091936281244, 49.980919372812444, 50.019080627187556, 50.01908063718756, 50.01908064718756, 50.569156532970474, 50.569156542970475, 50.569156552970476, 50.56915656297048, 50.56915657297048, 50.725101154478025, 50.725101164478026, 50.72510117447803, 50.72510118447803, 50.72510119447803, 50.72510120447803, 50.72510121447803, 50.72510122447803, 50.72510123447803, 50.72510124447803, 50.725101254478034, 51.00612476525916, 51.00612477525916, 51.00612478525916, 51.00612479525916, 51.00612480525916, 51.00612481525916, 51.006124825259164, 51.006124835259165, 51.007181199342476, 52.007328679628955, 52.007328689628956, 52.10506428372978, 52.26088246120417, 53.16115374936539, 53.16115375936539, 53.34693549363077, 53.34693550363077, 53.34693551363077, 53.34693552363077, 53.34693553363077, 53.350549334866805, 53.350549344866806, 54.45437527506251, 54.45437528506251, 54.45437529506251, 54.45437530506251, 54.454375315062514, 54.454375325062514, 54.454375335062515, 54.454375345062516, 54.45437535506252, 54.45437536506252, 55.24980452152199, 55.24980453152199, 55.31574607819376, 55.31574608819376, 55.31574609819376, 55.315746108193764, 55.315746118193765, ...
# Mean: 49.99803291237611
# Standard Deviation: 9.99215124487191
# Median: 50.0

# %%
# Graficamos los datos
utils.plot_histogram_with_stats(list_numbers_1, bins=7)

# %%
# Aproximamos un conjunto de datos con media 50, mediana 50, y desviación estándar 20

desired_sample_size = 300
desired_min = 1
desired_max = 100
desired_median = 50
desired_mean = 50
desired_std = 15
mean_error = 5
std_error = 5


list_numbers_2 = utils.generate_numbers(desired_sample_size, desired_min, desired_max, desired_median, desired_mean, desired_std, mean_error, std_error, max_iter=10000)

print("List:", list_numbers_2)
print("Mean:", np.mean(list_numbers_2))
print("Standard Deviation:", np.std(list_numbers_2))
print("Median:", np.median(list_numbers_2))
# Out:
# List: [1.0, 13.8056573602775, 14.987325939673436, 14.987325949673437, 14.987325959673438, 14.987325969673439, 14.98732597967344, 15.278210790451356, 15.278210800451356, 18.002922168359515, 18.002922178359515, 19.859045094163406, 19.859045104163407, 19.859045114163408, 19.85904512416341, 19.90534941272726, 20.147412071333793, 20.147412081333794, 20.147412091333795, 20.147412101333796, 20.766814693460482, 20.766814703460483, 22.44409302603198, 22.978394710913317, 22.987768219139184, 23.70010290042722, 23.70010291042722, 23.70010292042722, 23.70010293042722, 23.70010294042722, 23.77313220500832, 23.77313221500832, 23.77313222500832, 23.9107662524232, 24.48331306418405, 24.48331307418405, 24.48331308418405, 24.48331309418405, 24.483313104184052, 24.483313114184053, 24.802363092991545, 25.313316122182613, 26.23549602094276, 26.235496030942763, 26.235496040942763, 26.693525829567946, 27.1847532962247, 27.42666202435752, 27.42666203435752, 27.42666204435752, 27.745251662239006, 27.745251672239007, 27.745251682239008, 27.794184809708334, 29.780857362891613, 29.780857372891614, 29.780857382891615, 29.780857392891615, 29.989467739474783, 29.989467749474784, 29.989467759474785, 29.989467769474786, 29.989467779474786, 30.76331082553285, 30.763310835532852, 30.763310845532853, 31.579080687676303, 31.579080697676304, 31.579080707676304, 32.71912599036674, 32.71912600036674, 32.71912601036674, 32.719126020366744, 32.719126030366745, 32.719126040366746, 32.71912605036675, 33.74430821027183, 34.063075098891275, 34.063075108891276, 34.06307511889128, 34.06307512889128, 34.06307513889128, 35.27210853460091, 35.9314427472415, 35.9314427572415, 36.17853627340719, 37.426831680411844, 37.69087626996172, 37.69087627996172, 37.69087628996172, 37.69087629996172, 37.69087630996172, 37.80627634406569, 37.80627635406569, 37.80627636406569, 37.80627637406569, 37.853459026828766, 38.08679655927244, 38.54580482782073, 38.54580483782073, 38.54580484782073, 38.545804857820734, 38.545804867820735, 38.545804877820736, 38.545804887820736, 38.92566983453764, 38.925669844537644, 39.53831666975461, 39.7748886785157, 39.7748886885157, 39.7748886985157, 39.774888708515704, 39.774888718515705, 40.411464350754365, 40.43113044422474, 40.43113045422474, 40.49243035111334, 40.49243036111334, 41.35390494761947, 41.35390495761947, 41.35390496761947, 41.35390497761947, 41.35390498761947, 41.625835613130405, 41.625835623130406, 41.62583563313041, 43.528594462932695, 43.528594472932696, 43.5285944829327, 43.5285944929327, 44.253700855220934, 44.50856732688187, 45.534293346604926, 46.46476398893924, 47.15830068021003, 47.158300690210034, 47.158300700210035, 47.158300710210035, 47.22316106684554, 47.470686923112034, 47.470686933112034, 47.470686943112035, 48.54159510329077, 48.68953249590279, 49.09441026605196, 49.09441027605196, 49.318723550394765, 49.318723560394766, 49.627828230932295, 49.961144512740695, 50.038855487259305, 50.038855497259306, 50.224094066746915, 50.224094076746916, 50.49633981200573, 50.49633982200573, 51.80415402308855, 51.80415403308855, 51.80415404308855, 51.80415405308855, 52.62409559289046, 52.62409560289046, 52.70281881381284, 52.81435800720123, 53.13287297467688, 53.13287298467688, 53.13287299467688, 53.13287300467688, 53.13287301467688, 53.13287302467688, 53.132873034676884, 53.293432533299544, 54.934917731180846, 54.93491774118085, 54.93491775118085, 54.93491776118085, 54.93491777118085, 55.870197004804695, 56.597140661891274, 56.597140671891275, 57.73662576949655, 57.835256226695925, 57.889290304349196, 57.92692342907493, 58.395856850245195, 58.395856860245196, 58.3958568702452, 58.4507212975269, 58.4507213075269, 58.986274051358095, 58.986274061358095, 58.986274071358096, 58.9862740813581, 58.9862740913581, 59.04237390226614, 60.05518620923665, 60.05518621923665, 60.055186229236654, 60.055186239236654, 60.055186249236655, 60.055186259236656, 60.287511302264754, 60.287511312264755, 60.431171591592815, 60.747655637679756, 60.74765564767976, 61.27244 ...
# Mean: 49.97711056212213
# Standard Deviation: 19.984747818127907
# Median: 50.0

# %%
utils.plot_histogram_with_stats(list_numbers_2, bins=5)

# %%
# Aproximamos un conjunto de datos con media 60, mediana 80, y desviación estándar 24

desired_sample_size = 300
desired_min = 1
desired_max = 100
desired_median = 80
desired_mean = 50
desired_std = 15
mean_error = 10
std_error = 10


list_numbers_3 = utils.generate_numbers(desired_sample_size, desired_min, desired_max, desired_median, desired_mean, desired_std, mean_error, std_error, max_iter=10000)

print("List:", list_numbers_3)
print("Mean:", np.mean(list_numbers_3))
print("Standard Deviation:", np.std(list_numbers_3))
print("Median:", np.median(list_numbers_3))
# Out:
# List: [1.0, 14.695849626163003, 14.695849636163004, 17.879454108341278, 18.148917736815743, 18.227530944939314, 20.83255280247819, 22.84199095253804, 23.993968930773615, 23.993968940773616, 23.993968950773617, 23.993968960773618, 25.005630347203123, 25.005630357203124, 25.005630367203125, 25.65664714846092, 25.74456115047771, 25.744561160477712, 25.744561170477713, 25.744561180477714, 25.744561190477715, 25.941342012648924, 25.941342022648925, 25.941342032648926, 25.941342042648927, 25.941342052648928, 25.94134206264893, 25.94134207264893, 25.94134208264893, 25.94134209264893, 25.94134210264893, 25.941342112648933, 26.380868601336207, 26.380868611336208, 26.38086862133621, 26.38086863133621, 26.38086864133621, 26.66671258994094, 26.66671259994094, 26.66671260994094, 26.66671261994094, 26.666712629940942, 27.488581817876405, 27.488581827876406, 28.008576715821913, 28.008576725821914, 28.097969567631306, 30.000240847830142, 30.000240857830143, 30.947334787118788, 31.52751405569959, 31.936125828330454, 31.936125838330454, 31.936125848330455, 31.93911957870648, 31.939119588706482, 32.65540556388818, 32.65540557388818, 33.15808436159749, 33.6699296343788, 33.669929644378804, 33.669929654378805, 33.669929664378806, 33.66992967437881, 33.66992968437881, 34.15809215325357, 34.22922836802471, 34.22922837802471, 34.22922838802471, 34.373772006603076, 34.37377201660308, 36.15938279087304, 36.15938280087304, 36.795323873807384, 37.522618463294684, 37.782508922852244, 37.782508932852245, 37.782508942852246, 37.78250895285225, 37.78250896285225, 37.78250897285225, 37.78250898285225, 37.78250899285225, 37.78250900285225, 37.78250901285225, 37.78804407036593, 37.78804408036593, 37.96933651480337, 37.969336524803374, 37.969336534803375, 38.09410053278605, 38.09410054278605, 39.23563623815481, 40.17862179255994, 41.1920318415867, 41.1920318515867, 41.1920318615867, 42.26588851795564, 42.26588852795564, 42.67995673515195, 43.39290044941952, 43.62497026044764, 43.62497027044764, 43.62497028044764, 43.893988266491945, 43.893988276491946, 43.986368012521275, 44.8380923206964, 46.08621746557538, 46.08621747557538, 46.08621748557538, 46.08621749557538, 46.88766328301252, 46.88766329301252, 47.413624469008866, 47.41362447900887, 47.67388378663935, 48.13629645884356, 48.13629646884356, 48.13629647884356, 49.82653467261733, 50.21174724669581, 50.21174725669581, 50.21174726669581, 50.21174727669581, 50.62289964974677, 50.62289965974677, 52.555317900877235, 53.03029222326956, 53.03029223326956, 53.74414239215224, 54.823075224778414, 55.17932203299118, 55.17932204299118, 56.91808700644005, 56.91808701644005, 56.91808702644005, 56.91808703644005, 57.06144642781599, 57.06144643781599, 57.06144644781599, 57.06144645781599, 57.06144646781599, 57.06144647781599, 57.06144648781599, 57.06144649781599, 57.061446507815994, 57.061446517815995, 60.7049416279757, 79.99212551409633, 80.00787448590367, 80.00787449590366, 80.00787450590366, 80.00787451590365, 80.00787452590365, 80.00787453590364, 80.00787454590363, 80.00787455590363, 80.00787456590362, 80.00787457590361, 80.00787458590361, 80.10628274440772, 80.10628275440772, 80.10628276440771, 80.1062827744077, 80.1062827844077, 80.10628279440769, 80.10628280440768, 80.10628281440768, 80.10628282440767, 80.10628283440766, 80.10628284440766, 80.10628285440765, 80.10628286440765, 80.10628287440764, 80.10628288440763, 80.10628289440763, 80.10628290440762, 80.10628291440761, 80.10628292440761, 80.1062829344076, 80.1062829444076, 80.10628295440759, 80.10628296440758, 80.10628297440758, 80.10628298440757, 80.10628299440756, 80.10628300440756, 80.10628301440755, 80.10628302440755, 80.10628303440754, 80.10628304440753, 80.10628305440753, 80.10628306440752, 80.10628307440751, 80.23528741180984, 80.23528742180983, 80.23528743180982, 80.23528744180982, 80.23528745180981, 80.2352874618098, 80.2352874718098, 80.23528748180979, 80.23528749180979, 80.23528750180978, 80.23528751180977, 80.23528752180977, 80.40901429379848, 80.72605066 ...
# Mean: 59.99358561522424
# Standard Deviation: 24.077467056501092
# Median: 80.0

# %%
utils.plot_histogram_with_stats(list_numbers_3, bins=7)

# %%
# Aproximamos un conjunto de datos con media 40, mediana 30, y desviación estándar 24

desired_sample_size = 300
desired_min = 1
desired_max = 100
desired_median = 30
desired_mean = 40
desired_std = 15
mean_error = 10
std_error = 10


list_numbers_4 = utils.generate_numbers(desired_sample_size, desired_min, desired_max, desired_median, desired_mean, desired_std, mean_error, std_error, max_iter=10000)

print("List:", list_numbers_4)
print("Mean:", np.mean(list_numbers_4))
print("Standard Deviation:", np.std(list_numbers_4))
print("Median:", np.median(list_numbers_4))
# Out:
# List: [1.0, 2.306834303269536, 4.40916313084305, 4.40916314084305, 5.601584873608671, 7.20501406245563, 8.35692434823086, 8.356924358230861, 8.356924368230862, 9.362543428653757, 9.362543438653757, 9.362543448653758, 9.362543458653759, 9.36254346865376, 9.36254347865376, 9.362543488653762, 9.362543498653762, 9.362543508653763, 9.362543518653764, 9.362543528653765, 9.371963531056416, 9.371963541056417, 10.01585858106221, 10.017753801766663, 10.017753811766664, 10.048998762974257, 10.37305268657553, 10.373052696575531, 10.93567836997132, 10.935678379971321, 10.935678389971322, 10.935678399971323, 10.935678409971324, 10.935678419971325, 10.935678429971325, 10.935678439971326, 10.935678449971327, 10.935678459971328, 11.32828788339144, 11.32828789339144, 11.328287903391441, 12.800754276354777, 12.800754286354778, 12.800754296354778, 13.444409266675878, 13.444409276675879, 13.46585963225899, 13.465859642258991, 13.465859652258992, 14.11945340800782, 14.11945341800782, 14.119453428007821, 14.119453438007822, 15.213533251875198, 15.213533261875199, 15.2135332718752, 15.2135332818752, 15.213533291875201, 15.213533301875202, 15.213533311875203, 15.213533321875204, 15.73563401733763, 15.73563402733763, 15.73563403733763, 16.27290616462849, 16.375031512325638, 16.37503152232564, 16.41167878726024, 16.41167879726024, 17.43899792820433, 18.171597021656925, 18.31212470871091, 18.526766272705494, 18.526766282705495, 19.153805896481348, 19.75231534839311, 19.752315358393112, 19.986023266641958, 20.429051039366787, 20.429051049366787, 20.429051059366788, 20.640911776877186, 20.640911786877187, 20.640911796877187, 20.640911806877188, 21.35045969429255, 21.35045970429255, 21.35045971429255, 21.350459724292552, 21.350459734292553, 21.350459744292554, 22.054953689562133, 22.054953699562134, 22.054953709562135, 22.054953719562135, 22.054953729562136, 22.054953739562137, 23.311259598342094, 23.311259608342095, 23.311259618342095, 23.311259628342096, 23.311259638342097, 23.73128460332056, 23.73128461332056, 24.297009606221245, 25.557468624627436, 26.015437385260768, 26.01543739526077, 26.01543740526077, 26.01543741526077, 26.333060742243823, 26.333060752243824, 26.333060762243825, 26.333060772243826, 26.333060782243827, 26.333060792243828, 26.33306080224383, 26.33306081224383, 26.33306082224383, 26.33306083224383, 26.33306084224383, 26.333060852243833, 26.615804175148803, 26.615804185148804, 26.615804195148804, 26.615804205148805, 26.615804215148806, 26.75973870980204, 27.020454140576984, 27.9340334568388, 27.9340334668388, 27.934033476838803, 27.934033486838803, 27.934033496838804, 27.934033506838805, 27.968762072356057, 28.729810163010466, 29.469610168484984, 29.469610178484984, 29.469610188484985, 29.469610198484986, 29.469610208484987, 29.469610218484988, 29.710342198597303, 29.762555029777165, 29.762555039777165, 29.762555049777166, 29.762555059777167, 29.762555069777168, 29.9576286679092, 30.0423713320908, 33.50059602955193, 35.775575521862486, 37.15879023468728, 37.15879024468728, 37.15879025468728, 37.15879026468728, 37.158790274687284, 37.158790284687285, 37.20047295554158, 38.09314333918501, 38.54184534419619, 38.54184535419619, 39.39691861620144, 39.39691862620144, 39.963301825770436, 39.96330183577044, 39.96330184577044, 39.96330185577044, 39.96330186577044, 39.96330187577044, 39.96330188577044, 40.00333698126256, 40.00333699126256, 40.013015337928536, 40.06233543616199, 42.46273196979607, 42.46273197979607, 43.041350856372176, 43.04135086637218, 43.33038826126194, 43.33038827126194, 43.33038828126194, 44.323269509068886, 44.32326951906889, 45.36089795167607, 45.67967148357215, 45.726475169100944, 45.726475179100945, 45.726475189100945, 46.1250364433938, 47.13593061007807, 47.13593062007807, 47.13593063007807, 49.01494774691824, 49.7732156607762, 50.11435337603305, 50.11435338603305, 50.2591657583748, 50.99261521924328, 51.838927224217336, 51.83892723421734, 52.38508246792735, 53.026205221573406, 53.02620523157341, 53.3897709253498, 53.389 ...
# Mean: 40.004593646656005
# Standard Deviation: 24.997269460433653
# Median: 30.0

# %%
utils.plot_histogram_with_stats(list_numbers_4, bins=7)

# %% [markdown]
# # Otros tipos de gráficas

# %% [markdown]
# En esta sección veremos ejemplos de lso distintos tipos de gráficas vistos en clase

# %%
# Llamamos al DataFrame otra vez para poder visualizar los datos de neuvo sin tener que estar regresando
df
# Out:
#              id                         nombre  semestre  promedio  ingresos  \
# 0     IDHFI3552  Caridad Leonor Padrón Cavazos         7        86   13580.0
# 1     IDVOH5097       Aurelio Fabiola Anguiano         4        89   15993.0
# 2     IDFYS5079          Omar Amalia Sepúlveda         8        89   11008.0
# 3     IDSCE4123   Pamela Aida Cuellar Valverde         5        62   30926.0
# 4     IDYMU9480          Óscar Olivárez Nájera         7        66   24968.0
# ...         ...                            ...       ...       ...       ...
# 9995  IDURC8308    Inés Cynthia Madrid Salinas         7        86   17337.0
# 9996  IDJLX9083                   Mitzy Puente        10        74       NaN
# 9997  IDNCQ0036                Raquel Longoria         3        91   26994.0
# 9998  IDWJQ8803           Lic. Andrea Cisneros        10        87       NaN
# 9999  IDLPD1164    Maximiliano Alfonso Fuentes         5        68   22850.0
#
#       opinion_campus  trabaja  distancia_universidad  edad tipo_vivienda  \
# 0                 10    False                    NaN    21        Propia
# 1                  4     True                    1.0    22      Alquiler
# 2                  4    False                    1.0    18        Propia
# 3                 10    False                    1.0    17        Propia
# 4                 10    False                    1.0    26      Alquiler
# ...              ...      ...                    ...   ...           ...
# 9995              10     True                    1.0    37      Alquiler
# 9996               1    False                   10.0    17      Alquiler
# 9997              10     True                    NaN    27        Propia
# 9998               7     True                    3.0    26      Alquiler
# 9999               9     True                    NaN    23        Propia
#
#       horas_estudio  desertor
# 0                29         0
# 1                 5         0
# 2                11         0
# 3                12         0
# 4                17         0
# ...             ...       ...
# 9995             70         0
# 9996             88         0
# 9997             71         0
# 9998             74         0
# 9999            100         0
#
# [10000 rows x 12 columns]

# %%
# Obtenemos sus propiedades estadísticas para seleccionar los mejores ejemplos para cada tipo de gráfica
df.describe()
# Out:
#            semestre      promedio      ingresos  opinion_campus  \
# count  10000.000000  10000.000000   8107.000000    10000.000000
# mean       5.497200     79.752400  20319.281485        7.271800
# std        2.893964     11.743368   8143.080849        2.833254
# min        1.000000     60.000000   8300.000000        1.000000
# 25%        3.000000     70.000000  14035.000000        5.000000
# 50%        6.000000     80.000000  19972.000000        8.000000
# 75%        8.000000     90.000000  25908.500000       10.000000
# max       10.000000    100.000000  49329.000000       10.000000
#
#        distancia_universidad          edad  horas_estudio      desertor
# count            7977.000000  10000.000000   10000.000000  10000.000000
# mean                4.264385     20.888600      50.270400      0.187600
# std                 3.632390      3.855733      35.786128      0.390412
# min                 1.000000     17.000000       1.000000      0.000000
# 25%                 1.000000     17.000000      16.000000      0.000000
# 50%                 3.000000     20.000000      50.000000      0.000000
# 75%                 7.000000     23.000000      85.000000      0.000000
# max                25.000000     39.000000     100.000000      1.000000

# %% [markdown]
# ## Matriz de correlación

# %%
# Graficamos la matriz de corrleación entre las variables "semestre" y "promedio"

correlation_matrix = df[['semestre', 'promedio']].corr()

# Plot heatmap
sns.heatmap(correlation_matrix, annot=True, cmap="coolwarm", fmt=".2f")
plt.show()

# %% [markdown]
# ##

# %% [markdown]
# ## Boxplot

# %%
# Graficamos boxplot para la variable "semestre"

plt.figure(figsize=(6, 6))
sns.boxplot(data=df[['semestre']])
plt.show()

# %%
# Graficamos boxplot para la variable "ingresos"

plt.figure(figsize=(6, 6))
sns.boxplot(data=df[['ingresos']])
plt.show()

# %%
# Graficamos boxplot para la variable "edad"

plt.figure(figsize=(6, 6))
sns.boxplot(data=df[['edad']])
plt.show()

# %% [markdown]
# ## Pie chart

# %%
# Graficamos gráfica de pastel para la variable clase "desertor"

plt.figure(figsize=(6, 6))
df['desertor'].value_counts().plot.pie(autopct='%1.1f%%', cmap='coolwarm')
plt.title('Desertor')
plt.show()
