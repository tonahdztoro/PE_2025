# %% [markdown]
# # Definir Bibliotecas

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import utils

# %% [markdown]
# # Leer dataset como DataFrame

# %%
df = pd.read_csv('../Datasets/dataset.csv')
df
# Out:
#              id                         nombre  semestre  promedio  ingresos  \
# 0     IDHFI3552  Caridad Leonor Padrón Cavazos         7        86   13580.0
# 1     IDVOH5097       Aurelio Fabiola Anguiano         4        89   15993.0
# 2     IDFYS5079          Omar Amalia Sepúlveda         8        89   11008.0
# 3     IDSCE4123   Pamela Aida Cuellar Valverde         5        62   30926.0
# 4     IDYMU9480          Óscar Olivárez Nájera         7        66   24968.0
# ...         ...                            ...       ...       ...       ...
# 9995  IDURC8308    Inés Cynthia Madrid Salinas         7        86   17337.0
# 9996  IDJLX9083                   Mitzy Puente        10        74       NaN
# 9997  IDNCQ0036                Raquel Longoria         3        91   26994.0
# 9998  IDWJQ8803           Lic. Andrea Cisneros        10        87       NaN
# 9999  IDLPD1164    Maximiliano Alfonso Fuentes         5        68   22850.0
#
# ...

# %% [markdown]
# # Ver tipos de datos

# %%
df.dtypes
# Out:
# id                        object
# nombre                    object
# semestre                   int64
# promedio                   int64
# ingresos                 float64
# opinion_campus             int64
# trabaja                     bool
# distancia_universidad    float64
# edad                       int64
# tipo_vivienda             object
# horas_estudio              int64
# desertor                   int64
# dtype: object

# %% [markdown]
# # Calcular modas, medianas y medias

# %% [markdown]
# ## Modas

# %%
df.mode()
# Out:
#              id            nombre  semestre  promedio  ingresos  \
# 0     IDAAE3765      Bruno Flórez       1.0      74.0    8300.0
# 1     IDAAJ6279  Cornelio Vásquez       NaN       NaN       NaN
# 2     IDAAK9953     Dolores Salas       NaN       NaN       NaN
# 3     IDAAN0414     Gloria Fierro       NaN       NaN       NaN
# 4     IDAAN8457    Isabel Carrión       NaN       NaN       NaN
# ...         ...               ...       ...       ...       ...
# 9995  IDZZR7800               NaN       NaN       NaN       NaN
# 9996  IDZZU2201               NaN       NaN       NaN       NaN
# 9997  IDZZU4785               NaN       NaN       NaN       NaN
# 9998  IDZZU7053               NaN       NaN       NaN       NaN
# 9999  IDZZY4781               NaN       NaN       NaN       NaN
#
#       opinion_campus trabaja  distancia_universidad  edad tipo_vivienda  \
# 0               10.0   False                    1.0  17.0        Propia
# ...

# %%
df[['semestre', 'promedio', 'ingresos', 'opinion_campus', 'distancia_universidad', 'edad', 'tipo_vivienda', 'horas_estudio', 'desertor']].mode()
# Out:
#    semestre  promedio  ingresos  opinion_campus  distancia_universidad  edad  \
# 0         1        74    8300.0              10                    1.0    17
#
#   tipo_vivienda  horas_estudio  desertor
# 0        Propia             91         0

# %% [markdown]
# ## Medianas

# %%
df[['semestre', 'promedio', 'ingresos', 'opinion_campus', 'distancia_universidad', 'edad', 'horas_estudio']].median()
# Out:
# semestre                     6.0
# promedio                    80.0
# ingresos                 19972.0
# opinion_campus               8.0
# distancia_universidad        3.0
# edad                        20.0
# horas_estudio               50.0
# dtype: float64

# %% [markdown]
# ## Medias

# %%
df[['semestre', 'promedio', 'ingresos', 'opinion_campus', 'distancia_universidad', 'edad', 'horas_estudio', 'desertor']].mean()
# Out:
# semestre                     5.497200
# promedio                    79.752400
# ingresos                 20319.281485
# opinion_campus               7.271800
# distancia_universidad        4.264385
# edad                        20.888600
# horas_estudio               50.270400
# desertor                     0.187600
# dtype: float64

# %% [markdown]
# # Comprobar comprotamiento de los datos

# %%
column = 'semestre'

plt.figure(figsize=(10, 6))
plt.hist(df[column], bins=range(1, 12), edgecolor='black', align='left', rwidth=0.8)

# Customize the x-ticks to match the numbers in the data
plt.xticks(range(min(df[column]), max(df[column])+1 ))

# Show the plot
plt.title(f'Histogram of {column}')
plt.xlabel('Value')
plt.ylabel('Frequency')
plt.show()

# %%
column = 'promedio'

# Define los bordes de los bins para crear exactamente 10 barras entre 60 y 100
bins = np.linspace(60, 100, 11)  # 10 intervalos -> 11 bordes

plt.figure(figsize=(10, 6))
plt.hist(df[column], bins=bins, edgecolor='black', align='mid', rwidth=0.8)

# Ajusta las marcas del eje X para que coincidan con los valores medios de los bins
plt.xticks(np.arange(60, 101, 4))  # Aquí 4 es el ancho de cada intervalo (100-60)/10

# Mostrar el gráfico con título y etiquetas
plt.title(f'Histogram of {column}')
plt.xlabel('Value')
plt.ylabel('Frequency')
plt.show()

# %%
column = 'ingresos'

plt.figure(figsize=(10, 6))
plt.hist(df[column], bins=np.arange(int(min(df[column])), int(max(df[column])) + 2, max(df[column] - min(df[column]))/10), 
         edgecolor='black', align='left', rwidth=0.8)

# Customize the x-ticks to match the numbers in the data
plt.xticks(np.arange(min(df[column]), max(df[column])+1, 5000))

# Show the plot
plt.title(f'Histogram of {column}')
plt.xlabel('Value')
plt.ylabel('Frequency')
plt.show()

# %%
column = 'opinion_campus'

plt.figure(figsize=(10, 6))
plt.hist(df[column], bins=range(1, 12), edgecolor='black', align='left', rwidth=0.8)

# Customize the x-ticks to match the numbers in the data
plt.xticks(range(min(df[column]), max(df[column])+1 ))

# Show the plot
plt.title(f'Histogram of {column}')
plt.xlabel('Value')
plt.ylabel('Frequency')
plt.show()

# %%
column = 'trabaja'

plt.figure(figsize=(10, 6))
plt.hist(df[column].astype(int), 
         bins=[-0.5, 0.5, 1.5],  # Definimos bordes para alinear las barras con 0 y 1
         edgecolor='black', align='mid', rwidth=0.8)

# Configurar las etiquetas del eje X como 'False' y 'True'
plt.xticks([0, 1], labels=['False', 'True'])

# Títulos y etiquetas
plt.title(f'Histogram of {column}')
plt.xlabel('Value')
plt.ylabel('Frequency')
plt.show()

# %%
column = 'distancia_universidad'

plt.figure(figsize=(10, 6))
plt.hist(df[column], 
         bins=10, 
         edgecolor='black', align='left', rwidth=0.8)
plt.title(f'Histogram of {column}')
plt.xlabel('Value')
plt.ylabel('Frequency')
plt.show()

# %%
column = 'edad'

plt.figure(figsize=(10, 6))
plt.hist(df[column], 
         bins=np.arange(int(min(df[column])), int(max(df[column])) + 2, max(df[column] - min(df[column]))/10), 
         edgecolor='black', align='left', rwidth=0.8)
plt.title(f'Histogram of {column}')
plt.xlabel('Value')
plt.ylabel('Frequency')
plt.show()

# %%
column = 'tipo_vivienda'

plt.figure(figsize=(10, 6))
plt.hist(df[column], 
         bins=2, 
         edgecolor='black', align='mid', rwidth=0.8)
plt.title(f'Histogram of {column}')
plt.xlabel('Value')
plt.xticks(df[column].unique())
plt.ylabel('Frequency')
plt.show()

# %%
column = 'horas_estudio'

plt.figure(figsize=(10, 6))
plt.hist(df[column], 
         bins=np.arange(int(min(df[column])), int(max(df[column])) + 2, max(df[column] - min(df[column]))/10), 
         edgecolor='black', align='left', rwidth=0.8)
plt.title(f'Histogram of {column}')
plt.xlabel('Value')
plt.ylabel('Frequency')
plt.show()

# %%
column = 'desertor'

plt.figure(figsize=(10, 6))
plt.hist(df[column], 
         bins=2, 
         edgecolor='black', align='mid', rwidth=0.8)
plt.title(f'Histogram of {column}')
plt.xlabel('Value')
plt.xticks(df[column].unique())
plt.ylabel('Frequency')
plt.show()

# %% [markdown]
# # Ahora con todos los datos estadisticos

# %%
df.describe()
# Out:
#            semestre      promedio      ingresos  opinion_campus  \
# count  10000.000000  10000.000000   8107.000000    10000.000000
# mean       5.497200     79.752400  20319.281485        7.271800
# std        2.893964     11.743368   8143.080849        2.833254
# min        1.000000     60.000000   8300.000000        1.000000
# 25%        3.000000     70.000000  14035.000000        5.000000
# 50%        6.000000     80.000000  19972.000000        8.000000
# 75%        8.000000     90.000000  25908.500000       10.000000
# max       10.000000    100.000000  49329.000000       10.000000
#
#        distancia_universidad          edad  horas_estudio      desertor
# count            7977.000000  10000.000000   10000.000000  10000.000000
# mean                4.264385     20.888600      50.270400      0.187600
# std                 3.632390      3.855733      35.786128      0.390412
# min                 1.000000     17.000000       1.000000      0.000000
# ...

# %%
CV = df.describe().loc['std']/df.describe().loc['mean']
CV
# Out:
# semestre                 0.526443
# promedio                 0.147248
# ingresos                 0.400756
# opinion_campus           0.389622
# distancia_universidad    0.851797
# edad                     0.184586
# horas_estudio            0.711873
# desertor                 2.081087
# dtype: float64

# %% [markdown]
# # Distribuciones con distintas propiedades estadísticas

# %%
desired_sample_size = 300
desired_min = 1
desired_max = 100
desired_median = 50
desired_mean = 50
desired_std = 5
mean_error = 5
std_error = 5


list_numbers_1 = utils.generate_numbers(desired_sample_size, desired_min, desired_max, desired_median, desired_mean, desired_std, mean_error, std_error, max_iter=10000)

print("List:", list_numbers_1)
print("Mean:", np.mean(list_numbers_1))
print("Standard Deviation:", np.std(list_numbers_1))
print("Median:", np.median(list_numbers_1))
# Out:
# List: [1.0, 33.485277091599116, 34.49116157175542, 34.49116158175542, 34.49116159175542, 35.210179854945146, 35.62911021007757, 35.62911022007757, 35.88941951942108, 35.88941952942108, 35.889419539421084, 36.18072650064968, 36.180726510649684, 36.180726520649685, 36.180726530649686, 36.21453776317585, 36.55539213368022, 36.725507512672195, 36.725507522672196, 36.90494745874121, 36.90494746874121, 37.13087537845871, 37.13087538845871, 37.13087539845871, 37.372390113495946, 37.37239012349595, 37.37239013349595, 37.37239014349595, 38.02359453257094, 38.02359454257094, 38.02359455257094, 38.02359456257094, 38.02359457257094, 38.23024512045544, 38.318046399987196, 38.489443969823846, 38.48944397982385, 38.48944398982385, 38.48944399982385, 38.48944400982385, 38.48944401982385, 38.48944402982385, 38.48944403982385, 38.48944404982385, 38.570143531383536, 38.57014354138354, 38.57014355138354, 38.57014356138354, 38.57014357138354, 39.47445350001612, 39.47445351001612, 39.47445352001612, 39.47
# ...

# %%
utils.plot_histogram_with_stats(list_numbers_1, bins=7)

# %%
desired_sample_size = 300
desired_min = 1
desired_max = 100
desired_median = 50
desired_mean = 50
desired_std = 15
mean_error = 5
std_error = 5


list_numbers_2 = utils.generate_numbers(desired_sample_size, desired_min, desired_max, desired_median, desired_mean, desired_std, mean_error, std_error, max_iter=10000)

print("List:", list_numbers_2)
print("Mean:", np.mean(list_numbers_2))
print("Standard Deviation:", np.std(list_numbers_2))
print("Median:", np.median(list_numbers_2))
# Out:
# List: [1.0, 16.94673637786794, 16.94673638786794, 17.258336796658728, 17.25833680665873, 17.25833681665873, 17.25833682665873, 17.25833683665873, 17.258336846658732, 17.260912400448824, 17.880407461074658, 17.88040747107466, 17.88040748107466, 17.88040749107466, 17.88040750107466, 17.88040751107466, 18.22083351120215, 18.790979945382407, 19.292077077437177, 21.093422927709263, 21.093422937709263, 21.603640771346278, 21.60364078134628, 21.60364079134628, 21.86904391471798, 22.040584800643966, 22.040584810643967, 22.040584820643968, 22.04058483064397, 22.04058484064397, 22.071116819633918, 23.370987984337695, 23.893280837499265, 23.893280847499266, 23.893280857499267, 23.893280867499268, 26.145599669821696, 26.145599679821697, 26.185958855429348, 26.18595886542935, 26.18595887542935, 26.18595888542935, 26.18595889542935, 26.185958905429352, 27.0166376706272, 27.016637680627202, 27.016637690627203, 27.016637700627204, 27.016637710627204, 27.251991063986367, 27.251991073986368, 27.251991
# ...

# %%
utils.plot_histogram_with_stats(list_numbers_2, bins=5)

# %%
desired_sample_size = 300
desired_min = 1
desired_max = 100
desired_median = 80
desired_mean = 50
desired_std = 15
mean_error = 10
std_error = 10


list_numbers_3 = utils.generate_numbers(desired_sample_size, desired_min, desired_max, desired_median, desired_mean, desired_std, mean_error, std_error, max_iter=10000)

print("List:", list_numbers_3)
print("Mean:", np.mean(list_numbers_3))
print("Standard Deviation:", np.std(list_numbers_3))
print("Median:", np.median(list_numbers_3))
# Out:
# List: [1.0, 9.507791601440024, 12.794628456864494, 15.101487850448533, 17.07903552658931, 17.647025805120972, 17.943979016419256, 17.943979026419257, 17.943979036419258, 17.94397904641926, 17.94397905641926, 17.94397906641926, 17.94397907641926, 17.94397908641926, 18.39296267056577, 19.44212640674012, 19.72256908535798, 19.72256909535798, 19.72256910535798, 19.72256911535798, 19.722569125357982, 19.977786642750026, 20.19139376577334, 20.191393775773342, 20.191393785773343, 21.077677234157242, 21.077677244157243, 21.33368304753284, 21.33368305753284, 21.333683067532842, 22.24541066266373, 22.273047040008542, 22.38209229275768, 22.38209230275768, 22.38209231275768, 22.382092322757682, 23.30488628109976, 23.419595237853382, 23.419595247853383, 24.66853681511893, 24.66853682511893, 25.853650447395083, 25.853650457395084, 26.53969256333453, 26.53969257333453, 27.06047421216754, 27.445871976911576, 27.445871986911577, 27.445871996911578, 27.92562781733379, 28.337581452339997, 28.3375814623
# ...

# %%
utils.plot_histogram_with_stats(list_numbers_3, bins=7)

# %%
desired_sample_size = 300
desired_min = 1
desired_max = 100
desired_median = 30
desired_mean = 40
desired_std = 15
mean_error = 10
std_error = 10


list_numbers_4 = utils.generate_numbers(desired_sample_size, desired_min, desired_max, desired_median, desired_mean, desired_std, mean_error, std_error, max_iter=10000)

print("List:", list_numbers_4)
print("Mean:", np.mean(list_numbers_4))
print("Standard Deviation:", np.std(list_numbers_4))
print("Median:", np.median(list_numbers_4))
# Out:
# List: [1.0, 3.880274820239263, 6.865697231644033, 6.865697241644033, 7.1732845814594235, 7.173284591459423, 7.493291936896844, 7.493291946896844, 7.493291956896844, 7.493291966896844, 7.493291976896844, 7.4932919868968435, 7.493291996896843, 7.575772470013883, 7.76296341505149, 7.76296342505149, 7.909617584203599, 7.909617594203599, 7.909617604203599, 7.909617614203599, 7.909617624203599, 7.909617634203599, 7.909617644203599, 8.301533863593804, 8.301533873593804, 8.65092575272846, 8.65092576272846, 9.48935203037068, 9.489352040370681, 9.495314736419346, 9.495314746419346, 9.495314756419347, 9.495314766419348, 9.719783568552419, 10.16485639910367, 11.151808772674134, 12.374206759287453, 12.374206769287454, 12.374206779287455, 12.374206789287456, 13.423885605289785, 13.638964174080696, 13.638964184080697, 13.805756903738805, 13.805756913738806, 13.805756923738807, 15.232400243473478, 15.732512014447599, 15.7325120244476, 15.916317037656748, 15.916317047656749, 15.91631705765675, 15.916
# ...

# %%
utils.plot_histogram_with_stats(list_numbers_4, bins=7)

# %% [markdown]
# # Otros tipos de gráficas

# %%
df
# Out:
#              id                         nombre  semestre  promedio  ingresos  \
# 0     IDHFI3552  Caridad Leonor Padrón Cavazos         7        86   13580.0
# 1     IDVOH5097       Aurelio Fabiola Anguiano         4        89   15993.0
# 2     IDFYS5079          Omar Amalia Sepúlveda         8        89   11008.0
# 3     IDSCE4123   Pamela Aida Cuellar Valverde         5        62   30926.0
# 4     IDYMU9480          Óscar Olivárez Nájera         7        66   24968.0
# ...         ...                            ...       ...       ...       ...
# 9995  IDURC8308    Inés Cynthia Madrid Salinas         7        86   17337.0
# 9996  IDJLX9083                   Mitzy Puente        10        74       NaN
# 9997  IDNCQ0036                Raquel Longoria         3        91   26994.0
# 9998  IDWJQ8803           Lic. Andrea Cisneros        10        87       NaN
# 9999  IDLPD1164    Maximiliano Alfonso Fuentes         5        68   22850.0
#
# ...

# %%
df.describe()
# Out:
#            semestre      promedio      ingresos  opinion_campus  \
# count  10000.000000  10000.000000   8107.000000    10000.000000
# mean       5.497200     79.752400  20319.281485        7.271800
# std        2.893964     11.743368   8143.080849        2.833254
# min        1.000000     60.000000   8300.000000        1.000000
# 25%        3.000000     70.000000  14035.000000        5.000000
# 50%        6.000000     80.000000  19972.000000        8.000000
# 75%        8.000000     90.000000  25908.500000       10.000000
# max       10.000000    100.000000  49329.000000       10.000000
#
#        distancia_universidad          edad  horas_estudio      desertor
# count            7977.000000  10000.000000   10000.000000  10000.000000
# mean                4.264385     20.888600      50.270400      0.187600
# std                 3.632390      3.855733      35.786128      0.390412
# min                 1.000000     17.000000       1.000000      0.000000
# ...

# %% [markdown]
# ## Matriz de correlación

# %%
import seaborn as sns
correlation_matrix = df[['semestre', 'promedio']].corr()

# Plot heatmap
sns.heatmap(correlation_matrix, annot=True, cmap="coolwarm", fmt=".2f")
plt.show()

# %% [markdown]
# ##

# %% [markdown]
# ## Boxplot

# %%
# Plot box plot
plt.figure(figsize=(6, 6))
sns.boxplot(data=df[['semestre']])
plt.show()

# %%
# Plot box plot
plt.figure(figsize=(6, 6))
sns.boxplot(data=df[['ingresos']])
plt.show()

# %%
# Plot box plot
plt.figure(figsize=(6, 6))
sns.boxplot(data=df[['edad']])
plt.show()

# %% [markdown]
# ## Pie chart

# %%
# Plot pie chart
plt.figure(figsize=(6, 6))
df['desertor'].value_counts().plot.pie(autopct='%1.1f%%', cmap='coolwarm')
plt.title('Desertor')
plt.show()
